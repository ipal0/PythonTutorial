# %% [markdown]
# # Dynamic Typing

# %%
s = "PYTHON programming language"

# %%
type(s)
# Out:
# str

# %%
s = 12345

# %%
type(s)
# Out:
# int

# %%
s = 75.98

# %%
type(s)
# Out:
# float

# %%
s = ['red', 'blue', 'green']
type(s)
# Out:
# list

# %%
s = {'color':'red', 'quantity':25}
type(s)
# Out:
# dict

# %% [markdown]
# # Object Oriented

# %%
s = "PYTHON programming language"

# %%
s.lower()
# Out:
# 'python programming language'

# %%
s.upper()
# Out:
# 'PYTHON PROGRAMMING LANGUAGE'

# %%
s.lower().capitalize()
# Out:
# 'Python programming language'

# %%
s.split()
# Out:
# ['PYTHON', 'programming', 'language']

# %%
s.find('T')
# Out:
# 2

# %%
s.count('a')
# Out:
# 3

# %%
len(s)
# Out:
# 2

# %%
s.replace(' ','-')
# Out:
# 'PYTHON-programming-language'

# %%
s.swapcase()
# Out:
# 'python PROGRAMMING LANGUAGE'

# %%
s = {'color':'red', 'quantity':25}

# %%
s['color']
# Out:
# 'red'

# %%
s.keys()
# Out:
# dict_keys(['color', 'quantity'])

# %%
s.values()
# Out:
# dict_values(['red', 25])
